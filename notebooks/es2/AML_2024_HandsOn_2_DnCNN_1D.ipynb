# %% [markdown]
# <a href="https://colab.research.google.com/github/stefanogiagu/corso_AML_2024/blob/main/notebooks/es2/AML_2024_HandsOn_2_DnCNN_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Machine Learning for Physics 2021-2022
# ## Hands-on session 2
#
# Implementation in pytorch of a denoising CNN based on 1D convolutions and [residual learning](https://arxiv.org/abs/1512.03385), trained for the task of isolating the signal from spourious backgrounds in spectra from non-linear fast raman spectroscopy
#
# Based on a modified version of the DnCNN architecture ([K.Shang et al.](https://arxiv.org/abs/1608.03981)), modified for the new task and to work with one dimensional distributions
#
# *Stefano Giagu - v1.0 - 18.2.2022*
#
# *Stefano Giagu & Andrea - v1.1 - 08.3.2022* - A small addition to Residual learning and on how the number of  parameters is computed
#
# Andrea - v2.0 - 14.3.2023 - FillIn version, dilation and concatenation
#
# [SLIDE](https://docs.google.com/presentation/d/1UKUdn0qbDrKynkD8VQ4vVB40mDNi30TSaHMCJOm6EYI/edit?usp=sharing)

# %%
# needed libaries: numpy, matpoltlib, sklearn, torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from torchsummary import summary

import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)

import os.path
# Out:
# 2.1.0+cu121
# 0.16.0+cu121

# %%
# define device to use (cpu/gpu)
if torch.cuda.is_available():
  print('# of GPUs available: ', torch.cuda.device_count())
  print('First GPU type: ',torch.cuda.get_device_name(0))
device = ('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Computation device: {device}\n")
# Out:
# # of GPUs available:  1
# First GPU type:  Tesla T4
# Computation device: cuda

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! cd /content/gdrive/MyDrive

# %%
def CreateDir(path):
	# Create a directory if it does not exist
	success = os.path.exists(path)
	if not success:
		os.makedirs(path)
CreateDir("RamanDn")#your folder

# %%
pwd
# Out:
# '/content'

# %%
cd /content/gdrive/MyDrive/RamanDn
# Out:
# /content/gdrive/MyDrive/RamanDn

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/RamanDn'

# %% [markdown]
# # Load dataset
# - it will take a bit of time so please download it before the hands on session

# %%
my_file = "FSRamanSpectra_simulationFumero.zip"
if  os.path.exists(my_file):
    print("fle already donwloaded")

# %%
# download datasets
if not os.path.exists(my_file):
    # !wget http://giagu.web.cern.ch/giagu/CERN/FSRamanSpectra_simulationFumero.zip
# Out:
# --2024-03-11 15:30:34--  http://giagu.web.cern.ch/giagu/CERN/FSRamanSpectra_simulationFumero.zip
# Resolving giagu.web.cern.ch (giagu.web.cern.ch)... 188.184.21.205, 2001:1458:d00:34::100:59
# Connecting to giagu.web.cern.ch (giagu.web.cern.ch)|188.184.21.205|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 485975375 (463M) [application/zip]
# Saving to: ‘FSRamanSpectra_simulationFumero.zip’
#
# FSRamanSpectra_simu 100%[===================>] 463.46M  1.06MB/s    in 4m 12s
#
# 2024-03-11 15:34:48 (1.84 MB/s) - ‘FSRamanSpectra_simulationFumero.zip’ saved [485975375/485975375]

# %%
if not os.path.exists("FSRamanSpectra_simulationFumero/"):
    # !unzip FSRamanSpectra_simulationFumero.zip
else:
    print("Folder already exists")
# the zip file contains several examples of clean (ground truth) and  measured spectra
# (LowNoise, MixedNoise, August17_MixedNoise (a different model of noise with larger statistics), HighNoise).

# data is availabel as numpy tensors with shape:
# (5000,801): 5000 examples each one with 801 sampling of the fast raman distribution: LowNoise, MixedNoise, HighNoise
# (15000,801): 15000 examples for August17_MixedNoise
# Out:
# Archive:  FSRamanSpectra_simulationFumero.zip
#    creating: FSRamanSpectra_simulationFumero/
#   inflating: FSRamanSpectra_simulationFumero/Snoise_LowNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Snoise_HighNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Sclean_LowNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Sclean_MixedNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Sclean_August17_MixedNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Snoise_MixedNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Snoise_August17_MixedNoise.txt
#   inflating: FSRamanSpectra_simulationFumero/Sclean_HighNoise.txt

# %%
#read one of the datasets
# Let's use the low noise case
true = np.loadtxt('FSRamanSpectra_simulationFumero/Sclean_LowNoise.txt')
meas = np.loadtxt('FSRamanSpectra_simulationFumero/Snoise_LowNoise.txt')

true = true.transpose()
meas = meas.transpose()

true = true[:,0:-1]# 801 is a silly number when pooling is used, it is easier to discard the fast value
meas = meas[:,0:-1]

print('spectrum shape: ', true.shape)

# normalize all measured spectra amplitudes so that minimum is zero
for i in range(meas.shape[0]):
    max = meas[i].max()
    min = meas[i].min()
    if (max-min)>0:
        meas[i] = (meas[i] - min)

#plot few examples
plt.figure(figsize=(20,6))

for idx in range(6):
    plt.subplot(1,6,idx+1)
    plt.plot(true[idx], '-r',label="Clean (ground truth)")
    plt.plot(meas[idx], '-b',label="Noisy (input)")
    plt.legend()

plt.tight_layout()
plt.draw()
# Out:
# spectrum shape:  (5000, 800)

# %% [markdown]
# # Split the data in Train / Validation / Test
#
# # Add a channel dimention to the data
#  Conv1D operarion accetps a input shape of [batch, channels, (dimention to apply convoluntion, wavenumber in this case)]
#  We will first add it as last dim and then permute the order.

# %%
# training, validation, test split

testset_frac = 0.2 # test set fraction wrt whole samples
valiset_frac = 0.25 # validation set fraction wrt training+validation

X_train,X_test,Y_train,Y_test = train_test_split(meas,true,test_size=testset_frac, shuffle=True, random_state=1234)
X_train,X_vali,Y_train,Y_vali = train_test_split(X_train,Y_train,test_size=valiset_frac, shuffle=True, random_state=1234)

X_train = np.expand_dims(X_train, -1)
Y_train = np.expand_dims(Y_train, -1)
X_vali = np.expand_dims(X_vali, -1)
Y_vali = np.expand_dims(Y_vali, -1)
X_test = np.expand_dims(X_test, -1)
Y_test = np.expand_dims(Y_test, -1)

print('X_train shape: ',X_train.shape)
print('Y_train shape: ',Y_train.shape)
print('X_vali shape: ',X_vali.shape)
print('Y_vali shape: ',Y_vali.shape)
print('X_test shape: ',X_test.shape)
print('Y_test shape: ',Y_test.shape)
# Out:
# X_train shape:  (3000, 800, 1)
# Y_train shape:  (3000, 800, 1)
# X_vali shape:  (1000, 800, 1)
# Y_vali shape:  (1000, 800, 1)
# X_test shape:  (1000, 800, 1)
# Y_test shape:  (1000, 800, 1)

# %%
# transform numpy vectors to pytorch tensors

X_train_pt = torch.Tensor(X_train)
Y_train_pt = torch.Tensor(Y_train)
X_vali_pt = torch.Tensor(X_vali)
Y_vali_pt = torch.Tensor(Y_vali)
X_test_pt = torch.Tensor(X_test)
Y_test_pt = torch.Tensor(Y_test)

# switch channel dimension position as needed by pytorch (NOTE: in numpy/keras (dim1,dim2,..., channels) in pytorch (channel, dim1, dim2, ...))

X_train_pt = X_train_pt.permute(0,2,1)
Y_train_pt = Y_train_pt.permute(0,2,1)
X_vali_pt = X_vali_pt.permute(0,2,1)
Y_vali_pt = Y_vali_pt.permute(0,2,1)
X_test_pt = X_test_pt.permute(0,2,1)
Y_test_pt = Y_test_pt.permute(0,2,1)

print(X_train_pt.shape)
print(Y_train_pt.shape)
print(X_vali_pt.shape)
print(Y_vali_pt.shape)
print(X_test_pt.shape)
print(Y_test_pt.shape)
# Out:
# torch.Size([3000, 1, 800])
# torch.Size([3000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])
# torch.Size([1000, 1, 800])

# %% [markdown]
# # A very informal explanation on why we use residual learning. Read the paper for a better explanation
#
# Trainig a neural network $NN_W(x)$ means finding the best set of weigths $W$ that minimize the Loss function $\sum_{train} L_W(y,\tilde y)$ where $ \tilde y = NN_w(x)$ is the network prediction.
#
# If X is a corrupted  version of y to which is added a source of noise $\epsilon$ (so $X = y + \epsilon$), then the denosing task is to restore the original signal y from the noisy observation X.
#
# In this case the loss can be written as (using a L2 loss as an example):
# $$
# L_W(y,\tilde y) = (y-\tilde y)^2
# $$
#
# Clearly, one solution that minimize the loss is that the output of the network $\tilde y$ match the original sample y.
#
# We can try to solve an easier task teaching the network to remove the noise instead of restore the target. If the noise structure is simpler than the signal (as in most cases) then the network may converge faster and obtain better performance.
#
# In this case we can set the output of the network to be
# $$
# NN_W(X) = X - \tilde y
# $$
#
# Thus the loss can be written as (remenber that $X = y + \epsilon$)
#
# $$
# L_W(y,X-\tilde y) = (y- X - \tilde y)^2 =  (y - y + \epsilon - \tilde y)^2 = ( \epsilon - \tilde y)^2
# $$
#
# In this case a good solution for the task is to reproduce the noisy part of the signal.
#
# In the case of Raman spectra there are two different souces of "corruption": A slow varying baseline and a fast uncorrelated nosise. Still, residual learning will work very well if they are both additive respect to the real signal.

# %%
# Definition of the ANN model: DnCNN 1 Dimensional
# as in the orginal paper: architecture conv1d + 15 x conv1d + BN + relu + conv1d output and residual layer
from torch import nn
import torch.nn.functional as F

# define the network by inerithing from nn.Module class
class DnCNN(nn.Module):
  def __init__(self, num_layers=15):
    super(DnCNN, self).__init__()
    self.num_layers=num_layers

    # define layers of the first block
    # 1D convolution (https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html)
    # input 1 channel --> output 64 channels (i.e. convolutional filters)
    self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=10, padding='same', bias=False)
    self.relu1 = nn.ReLU()

    # central blocks: num_layers blocks with conv1d + BN + relu activation
    hlayers = []
    for _ in range(num_layers):
      hlayers.append(nn.Conv1d(in_channels=64, out_channels=64, kernel_size=10, padding='same', bias=False))
      #hlayers.append(nn.BatchNorm1d(64)) # From Andrea: In my experience, it improves convergence for large batches since it allows a larger learning rate. Try to experimetn with it
      hlayers.append(nn.ReLU())

    self.central_block = nn.Sequential(*hlayers)

    # output block: 64 channels --> 1 output channel (i.e. the original image)
    self.conv3 = nn.Conv1d(in_channels=64, out_channels=1, kernel_size=10, padding='same', bias=False)

  # forward pass: x (input) -> out
  def forward(self, x):
    out = self.relu1(self.conv1(x))
    out = self.central_block(out)
    out = self.conv3(out)

    # residual learning (this way out become the clean spectrum and the network has only to learn the "noise")
    out = x - out
    return out

# %% [markdown]
# # Visualize the model architecture and compute the parameters
#
# - The first layer has a kernel size of 10 (it is a windows of length 10 that runs on the spectra). The input is 1D and there is no bias so it has 10 (10x1 + 0) parameters. The layer has 64 of these kernels so the total number of parameters is 64 * 10 = 640
#
# - The others layer have also a kernel size of 10 but its input has now 64 channels (the number of kernels of the previous layer) so each kernel has 64*10 + 0 parameters. The layers have 64 of these kernels so the total number of parameters is 64 * 64 * 10 = 40960.
#
# - How many paramenters has the last layer?

# %%
# instantiate the model
model = DnCNN(num_layers=15)
#model = UNet1D(1,1,32)
#model = DilatedResidualConvNet(1,1)
print(model)

# this is a useful tool to print the structure of the model in a keras-like fashion ...
from torchsummary import summary
if torch.cuda.is_available():
  summary(model.cuda(), input_size=(1,800))
else:
  summary(model, input_size=(1,800))
# Out:
# DnCNN(
#   (conv1): Conv1d(1, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#   (relu1): ReLU()
#   (central_block): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (1): ReLU()
#     (2): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (3): ReLU()
#     (4): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (5): ReLU()
#     (6): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (7): ReLU()
#     (8): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (9): ReLU()
#     (10): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (11): ReLU()
#     (12): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (13): ReLU()
#     (14): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (15): ReLU()
#     (16): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (17): ReLU()
#     (18): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (19): ReLU()
#     (20): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (21): ReLU()
#     (22): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (23): ReLU()
#     (24): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (25): ReLU()
#     (26): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (27): ReLU()
#     (28): Conv1d(64, 64, kernel_size=(10,), stride=(1,), padding=same, bias=False)
#     (29): ReLU()
#   )
#   (conv3): Conv1d(64, 1, kernel_size=(10,), stride=(1,), padding=same, bias=False)
# )
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1008.)
#   return F.conv1d(input, weight, bias, self.stride,
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 64, 800]             640
#               ReLU-2              [-1, 64, 800]               0
#             Conv1d-3              [-1, 64, 800]          40,960
#               ReLU-4              [-1, 64, 800]               0
#             Conv1d-5              [-1, 64, 800]          40,960
#               ReLU-6              [-1, 64, 800]               0
#             Conv1d-7              [-1, 64, 800]          40,960
#               ReLU-8              [-1, 64, 800]               0
#             Conv1d-9              [-1, 64, 800]          40,960
#              ReLU-10              [-1, 64, 800]               0
#            Conv1d-11              [-1, 64, 800]          40,960
#              ReLU-12              [-1, 64, 800]               0
#            Conv1d-13              [-1, 64, 800]          40,960
#              ReLU-14              [-1, 64, 800]               0
#            Conv1d-15              [-1, 64, 800]          40,960
#              ReLU-16              [-1, 64, 800]               0
#            Conv1d-17              [-1, 64, 800]          40,960
#              ReLU-18              [-1, 64, 800]               0
#            Conv1d-19              [-1, 64, 800]          40,960
#              ReLU-20              [-1, 64, 800]               0
#            Conv1d-21              [-1, 64, 800]          40,960
#              ReLU-22              [-1, 64, 800]               0
#            Conv1d-23              [-1, 64, 800]          40,960
#              ReLU-24              [-1, 64, 800]               0
#            Conv1d-25              [-1, 64, 800]          40,960
#              ReLU-26              [-1, 64, 800]               0
#            Conv1d-27              [-1, 64, 800]          40,960
#              ReLU-28              [-1, 64, 800]               0
#            Conv1d-29              [-1, 64, 800]          40,960
#              ReLU-30              [-1, 64, 800]               0
#            Conv1d-31              [-1, 64, 800]          40,960
#              ReLU-32              [-1, 64, 800]               0
#            Conv1d-33               [-1, 1, 800]             640
# ================================================================
# Total params: 615,680
# Trainable params: 615,680
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 12.51
# Params size (MB): 2.35
# Estimated Total Size (MB): 14.86
# ----------------------------------------------------------------

# %%
# define loss function, monitoring metric and optmizer

#loss MSE
loss_func = nn.MSELoss()

#metric MAE (called L1Loss in pytorch)
metric_func = nn.L1Loss()

# optimizer: Adam
from torch import optim
opt = optim.Adam(model.parameters(), lr=1e-3)

# scheduler for step decay lr schedule
scheduler = optim.lr_scheduler.StepLR(opt, 20, gamma=0.1, last_epoch=-1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
# move the model into the GPU
model.to('cpu')
print('The model is in the: ', next(model.parameters()).device)
model.to(device)
print('now the model is in the: ', next(model.parameters()).device)
# Out:
# The model is in the:  cpu
# now the model is in the:  cuda:0

# %%
#Checkpoints (to save model parameters during training)
class SaveBestModel:
    def __init__(self, best_valid_loss=float('inf')): #object initialized with best_loss = +infinite
        self.best_valid_loss = best_valid_loss

    def __call__(
        self, current_valid_loss,
        epoch, model, optimizer, criterion, metric,
    ):
        if current_valid_loss < self.best_valid_loss:
            self.best_valid_loss = current_valid_loss
            print(f"\nBest validation loss: {self.best_valid_loss}")
            print(f"\nSaving best model for epoch: {epoch+1}\n")
            # method to save a model (the state_dict: a python dictionary object that
            # maps each layer to its parameter tensor) and other useful parametrers
            # see: https://pytorch.org/tutorials/beginner/saving_loading_models.html
            torch.save({
                'epoch': epoch+1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': criterion,
                'metric': metric,
                }, 'best_model.pth')

# %%
# training parameters

epochs = 80
batch_size = 128# was 32

# define dataloaders
from torch.utils.data import TensorDataset, DataLoader

dataset_train = TensorDataset(X_train_pt, Y_train_pt)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

dataset_vali = TensorDataset(X_vali_pt, Y_vali_pt)
dataloader_vali = DataLoader(dataset_vali, batch_size=batch_size)

# %%
#training loop

import time

save_best_model = SaveBestModel()

# lists to save loss and metric history
hist_loss = []
hist_metric = []
hist_vloss = []
hist_vmetric = []

#loop over epochs
for epoch in range(epochs):
    t0 = time.time()

    #training step
    model.train()

    train_loss = 0.0
    train_metric = 0.0
    counter = 0
    for xb, yb in dataloader_train: #takes a batch from the train dataloader
        counter += 1
        xb=xb.type(torch.float).to(device) #move troch tensors to device (cpu or GPU)
        yb=yb.type(torch.float).to(device)

        pred = model(xb) #get prediction for batch
        loss = loss_func(pred, yb) #compute loss
        metric = metric_func(pred, yb) #compute metric

        train_loss += loss.item() #update total loss
        train_metric += metric.item() #update total metric

        # backpropagation
        loss.backward()
        # update weights
        opt.step()
        # set to zero gradients for the next step
        opt.zero_grad()

    # normalize loss and metric by number of batches
    train_loss = train_loss/counter
    train_metric = train_metric/counter

    # update history
    hist_loss.append(train_loss)
    hist_metric.append(train_metric)


    # evaluation setp (same as trainign but w/o backpropagation)
    model.eval()

    vali_loss = 0.0
    vali_metric = 0.0
    counter = 0
    with torch.no_grad():
      for xb, yb in dataloader_vali:
        counter += 1
        xb=xb.type(torch.float).to(device)
        yb=yb.type(torch.float).to(device)
        pred = model(xb)
        vloss = loss_func(pred, yb)
        vmetric = metric_func(pred, yb)
        vali_loss += vloss.item()
        vali_metric += vmetric.item()

    vali_loss = vali_loss/counter
    vali_metric = vali_metric/counter

    hist_vloss.append(vali_loss)
    hist_vmetric.append(vali_metric)

    #save best model
    save_best_model(vali_loss, epoch, model, opt, loss_func, metric_func)

    elapsed_time = time.time()-t0
    print("epoch: %d, time(s): %.4f, train loss: %.6f, train metric: %.6f, vali loss: %.6f, vali metric: %.6f" % (epoch+1, elapsed_time, train_loss, train_metric, vali_loss, vali_metric))

    # update learning rate schedule
    scheduler.step()
# Out:
# Best validation loss: 0.2112016249448061
#
# Saving best model for epoch: 1
#
# epoch: 1, time(s): 3.9325, train loss: 0.173478, train metric: 0.290599, vali loss: 0.211202, vali metric: 0.325881
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.17579839006066322
#
# Saving best model for epoch: 2
#
# epoch: 2, time(s): 2.9167, train loss: 0.181463, train metric: 0.294509, vali loss: 0.175798, vali metric: 0.296564
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.014778790064156055
#
# Saving best model for epoch: 3
#
# epoch: 3, time(s): 2.9089, train loss: 0.049242, train metric: 0.132945, vali loss: 0.014779, vali metric: 0.075698
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.003075085987802595
#
# Saving best model for epoch: 4
#
# epoch: 4, time(s): 2.9205, train loss: 0.005573, train metric: 0.035625, vali loss: 0.003075, vali metric: 0.019456
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0017968408792512491
#
# Saving best model for epoch: 5
#
# epoch: 5, time(s): 2.9334, train loss: 0.002833, train metric: 0.023922, vali loss: 0.001797, vali metric: 0.020709
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0009292020622524433
#
# Saving best model for epoch: 6
#
# epoch: 6, time(s): 2.9409, train loss: 0.001547, train metric: 0.019866, vali loss: 0.000929, vali metric: 0.014145
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 7, time(s): 2.9019, train loss: 0.000918, train metric: 0.016165, vali loss: 0.001100, vali metric: 0.023265
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.000497134002216626
#
# Saving best model for epoch: 8
#
# epoch: 8, time(s): 2.9608, train loss: 0.000640, train metric: 0.013335, vali loss: 0.000497, vali metric: 0.011970
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0004470522835617885
#
# Saving best model for epoch: 9
#
# epoch: 9, time(s): 2.9602, train loss: 0.000524, train metric: 0.012485, vali loss: 0.000447, vali metric: 0.012435
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 10, time(s): 2.9216, train loss: 0.000481, train metric: 0.012337, vali loss: 0.000449, vali metric: 0.012119
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0004413966235006228
#
# Saving best model for epoch: 11
#
# epoch: 11, time(s): 2.9771, train loss: 0.000491, train metric: 0.012301, vali loss: 0.000441, vali metric: 0.012309
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0004249260382493958
#
# Saving best model for epoch: 12
#
# epoch: 12, time(s): 2.9788, train loss: 0.000462, train metric: 0.011773, vali loss: 0.000425, vali metric: 0.011832
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 13, time(s): 2.9439, train loss: 0.000469, train metric: 0.012266, vali loss: 0.000462, vali metric: 0.011912
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 14, time(s): 2.9571, train loss: 0.000473, train metric: 0.011831, vali loss: 0.000490, vali metric: 0.014792
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 15, time(s): 2.9644, train loss: 0.000495, train metric: 0.012838, vali loss: 0.000511, vali metric: 0.015532
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.0003623005723056849
#
# Saving best model for epoch: 16
#
# epoch: 16, time(s): 3.0094, train loss: 0.000509, train metric: 0.012992, vali loss: 0.000362, vali metric: 0.010870
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 17, time(s): 2.9661, train loss: 0.000613, train metric: 0.014629, vali loss: 0.000453, vali metric: 0.011127
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 18, time(s): 2.9715, train loss: 0.000695, train metric: 0.014625, vali loss: 0.000424, vali metric: 0.011388
# Adjusting learning rate of group 0 to 1.0000e-03.
# epoch: 19, time(s): 2.9956, train loss: 0.000606, train metric: 0.014322, vali loss: 0.000417, vali metric: 0.013609
# Adjusting learning rate of group 0 to 1.0000e-03.
#
# Best validation loss: 0.00030813827288511675
#
# Saving best model for epoch: 20
#
# epoch: 20, time(s): 3.0450, train loss: 0.000463, train metric: 0.012773, vali loss: 0.000308, vali metric: 0.009809
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002878087489079917
#
# Saving best model for epoch: 21
#
# epoch: 21, time(s): 3.0503, train loss: 0.000340, train metric: 0.009840, vali loss: 0.000288, vali metric: 0.009405
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00027875051273440477
#
# Saving best model for epoch: 22
#
# epoch: 22, time(s): 3.0554, train loss: 0.000331, train metric: 0.009546, vali loss: 0.000279, vali metric: 0.009355
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00027330531702318694
#
# Saving best model for epoch: 23
#
# epoch: 23, time(s): 3.0853, train loss: 0.000318, train metric: 0.009331, vali loss: 0.000273, vali metric: 0.009115
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00026781196356751025
#
# Saving best model for epoch: 24
#
# epoch: 24, time(s): 3.0823, train loss: 0.000312, train metric: 0.009199, vali loss: 0.000268, vali metric: 0.009177
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 25, time(s): 3.0354, train loss: 0.000308, train metric: 0.009098, vali loss: 0.000275, vali metric: 0.009665
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002630533890624065
#
# Saving best model for epoch: 26
#
# epoch: 26, time(s): 3.0892, train loss: 0.000304, train metric: 0.009082, vali loss: 0.000263, vali metric: 0.009226
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002610899209685158
#
# Saving best model for epoch: 27
#
# epoch: 27, time(s): 3.1184, train loss: 0.000303, train metric: 0.009110, vali loss: 0.000261, vali metric: 0.008864
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00025698222270875704
#
# Saving best model for epoch: 28
#
# epoch: 28, time(s): 3.1010, train loss: 0.000297, train metric: 0.009023, vali loss: 0.000257, vali metric: 0.009053
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 29, time(s): 3.0594, train loss: 0.000297, train metric: 0.008971, vali loss: 0.000258, vali metric: 0.009110
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00025361782900290564
#
# Saving best model for epoch: 30
#
# epoch: 30, time(s): 3.1084, train loss: 0.000294, train metric: 0.008973, vali loss: 0.000254, vali metric: 0.008885
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 31, time(s): 3.0725, train loss: 0.000322, train metric: 0.008919, vali loss: 0.000264, vali metric: 0.009755
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002493269585102098
#
# Saving best model for epoch: 32
#
# epoch: 32, time(s): 3.1255, train loss: 0.000287, train metric: 0.008915, vali loss: 0.000249, vali metric: 0.008822
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002462364500388503
#
# Saving best model for epoch: 33
#
# epoch: 33, time(s): 3.1262, train loss: 0.000286, train metric: 0.008917, vali loss: 0.000246, vali metric: 0.008760
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 34, time(s): 3.0990, train loss: 0.000285, train metric: 0.008883, vali loss: 0.000261, vali metric: 0.009827
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00024482473236275837
#
# Saving best model for epoch: 35
#
# epoch: 35, time(s): 3.1622, train loss: 0.000285, train metric: 0.008911, vali loss: 0.000245, vali metric: 0.009021
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00024092989588098135
#
# Saving best model for epoch: 36
#
# epoch: 36, time(s): 3.1546, train loss: 0.000282, train metric: 0.008869, vali loss: 0.000241, vali metric: 0.008841
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 37, time(s): 3.1044, train loss: 0.000273, train metric: 0.008662, vali loss: 0.000243, vali metric: 0.008762
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.0002371039900026517
#
# Saving best model for epoch: 38
#
# epoch: 38, time(s): 3.1761, train loss: 0.000272, train metric: 0.008683, vali loss: 0.000237, vali metric: 0.008485
# Adjusting learning rate of group 0 to 1.0000e-04.
#
# Best validation loss: 0.00023473190412914846
#
# Saving best model for epoch: 39
#
# epoch: 39, time(s): 3.1857, train loss: 0.000270, train metric: 0.008588, vali loss: 0.000235, vali metric: 0.008617
# Adjusting learning rate of group 0 to 1.0000e-04.
# epoch: 40, time(s): 3.1452, train loss: 0.000272, train metric: 0.008591, vali loss: 0.000236, vali metric: 0.008703
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.0002300463784195017
#
# Saving best model for epoch: 41
#
# epoch: 41, time(s): 3.2065, train loss: 0.000263, train metric: 0.008470, vali loss: 0.000230, vali metric: 0.008514
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022925037956156302
#
# Saving best model for epoch: 42
#
# epoch: 42, time(s): 3.2029, train loss: 0.000262, train metric: 0.008405, vali loss: 0.000229, vali metric: 0.008419
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 43, time(s): 3.1708, train loss: 0.000261, train metric: 0.008352, vali loss: 0.000230, vali metric: 0.008605
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022883445308252703
#
# Saving best model for epoch: 44
#
# epoch: 44, time(s): 3.2130, train loss: 0.000293, train metric: 0.008423, vali loss: 0.000229, vali metric: 0.008535
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 45, time(s): 3.1807, train loss: 0.000264, train metric: 0.008451, vali loss: 0.000231, vali metric: 0.008643
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022880802498548292
#
# Saving best model for epoch: 46
#
# epoch: 46, time(s): 3.2275, train loss: 0.000259, train metric: 0.008319, vali loss: 0.000229, vali metric: 0.008497
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022819794321549125
#
# Saving best model for epoch: 47
#
# epoch: 47, time(s): 3.2330, train loss: 0.000258, train metric: 0.008333, vali loss: 0.000228, vali metric: 0.008471
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 48, time(s): 3.1808, train loss: 0.000260, train metric: 0.008323, vali loss: 0.000230, vali metric: 0.008575
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.0002278874053445179
#
# Saving best model for epoch: 49
#
# epoch: 49, time(s): 3.2415, train loss: 0.000262, train metric: 0.008409, vali loss: 0.000228, vali metric: 0.008463
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 50, time(s): 3.1808, train loss: 0.000262, train metric: 0.008350, vali loss: 0.000229, vali metric: 0.008495
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 51, time(s): 3.1763, train loss: 0.000257, train metric: 0.008312, vali loss: 0.000228, vali metric: 0.008558
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022715559316566214
#
# Saving best model for epoch: 52
#
# epoch: 52, time(s): 3.2310, train loss: 0.000258, train metric: 0.008308, vali loss: 0.000227, vali metric: 0.008505
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 53, time(s): 3.1741, train loss: 0.000258, train metric: 0.008324, vali loss: 0.000228, vali metric: 0.008459
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022687469754600897
#
# Saving best model for epoch: 54
#
# epoch: 54, time(s): 3.2134, train loss: 0.000259, train metric: 0.008328, vali loss: 0.000227, vali metric: 0.008406
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 55, time(s): 3.1639, train loss: 0.000258, train metric: 0.008367, vali loss: 0.000227, vali metric: 0.008555
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022677563902107067
#
# Saving best model for epoch: 56
#
# epoch: 56, time(s): 3.2316, train loss: 0.000258, train metric: 0.008325, vali loss: 0.000227, vali metric: 0.008512
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022636306675849482
#
# Saving best model for epoch: 57
#
# epoch: 57, time(s): 3.2083, train loss: 0.000256, train metric: 0.008259, vali loss: 0.000226, vali metric: 0.008476
# Adjusting learning rate of group 0 to 1.0000e-05.
# epoch: 58, time(s): 3.1612, train loss: 0.000261, train metric: 0.008320, vali loss: 0.000227, vali metric: 0.008557
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022609648112847935
#
# Saving best model for epoch: 59
#
# epoch: 59, time(s): 3.2086, train loss: 0.000255, train metric: 0.008327, vali loss: 0.000226, vali metric: 0.008362
# Adjusting learning rate of group 0 to 1.0000e-05.
#
# Best validation loss: 0.00022580752920475788
#
# Saving best model for epoch: 60
#
# epoch: 60, time(s): 3.2303, train loss: 0.000258, train metric: 0.008301, vali loss: 0.000226, vali metric: 0.008518
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00022569106477021705
#
# Saving best model for epoch: 61
#
# epoch: 61, time(s): 3.1993, train loss: 0.000256, train metric: 0.008343, vali loss: 0.000226, vali metric: 0.008489
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 62, time(s): 3.1648, train loss: 0.000257, train metric: 0.008326, vali loss: 0.000226, vali metric: 0.008476
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 63, time(s): 3.1507, train loss: 0.000260, train metric: 0.008292, vali loss: 0.000226, vali metric: 0.008459
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 64, time(s): 3.1694, train loss: 0.000258, train metric: 0.008358, vali loss: 0.000226, vali metric: 0.008474
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 65, time(s): 3.1534, train loss: 0.000258, train metric: 0.008276, vali loss: 0.000226, vali metric: 0.008459
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 66, time(s): 3.1623, train loss: 0.000255, train metric: 0.008290, vali loss: 0.000226, vali metric: 0.008483
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.0002256462466903031
#
# Saving best model for epoch: 67
#
# epoch: 67, time(s): 3.1997, train loss: 0.000256, train metric: 0.008287, vali loss: 0.000226, vali metric: 0.008448
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 68, time(s): 3.1642, train loss: 0.000257, train metric: 0.008303, vali loss: 0.000226, vali metric: 0.008463
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 69, time(s): 3.1619, train loss: 0.000255, train metric: 0.008277, vali loss: 0.000226, vali metric: 0.008464
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 70, time(s): 3.1682, train loss: 0.000256, train metric: 0.008270, vali loss: 0.000226, vali metric: 0.008475
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.0002255310300824931
#
# Saving best model for epoch: 71
#
# epoch: 71, time(s): 3.2096, train loss: 0.000253, train metric: 0.008240, vali loss: 0.000226, vali metric: 0.008441
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 72, time(s): 3.1677, train loss: 0.000256, train metric: 0.008305, vali loss: 0.000226, vali metric: 0.008477
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 73, time(s): 3.1667, train loss: 0.000255, train metric: 0.008240, vali loss: 0.000226, vali metric: 0.008450
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 74, time(s): 3.1613, train loss: 0.000257, train metric: 0.008315, vali loss: 0.000226, vali metric: 0.008471
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00022548052220372483
#
# Saving best model for epoch: 75
#
# epoch: 75, time(s): 3.2080, train loss: 0.000256, train metric: 0.008284, vali loss: 0.000225, vali metric: 0.008446
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 76, time(s): 3.1608, train loss: 0.000255, train metric: 0.008261, vali loss: 0.000226, vali metric: 0.008465
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 77, time(s): 3.1718, train loss: 0.000255, train metric: 0.008262, vali loss: 0.000226, vali metric: 0.008482
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 78, time(s): 3.1635, train loss: 0.000262, train metric: 0.008321, vali loss: 0.000226, vali metric: 0.008477
# Adjusting learning rate of group 0 to 1.0000e-06.
#
# Best validation loss: 0.00022541695398103911
#
# Saving best model for epoch: 79
#
# epoch: 79, time(s): 3.2236, train loss: 0.000259, train metric: 0.008342, vali loss: 0.000225, vali metric: 0.008446
# Adjusting learning rate of group 0 to 1.0000e-06.
# epoch: 80, time(s): 3.1735, train loss: 0.000256, train metric: 0.008311, vali loss: 0.000226, vali metric: 0.008444
# Adjusting learning rate of group 0 to 1.0000e-07.

# %%
# plot metric (MAE) history

plt.figure(figsize=(10, 7))
plt.plot(range(1,len(hist_metric)+1), hist_metric,  color='green', linestyle='-', label='train metric')
plt.plot(range(1,len(hist_vmetric)+1),hist_vmetric, color='blue', linestyle='-', label='validation metric')
plt.xlabel('Epochs')
plt.ylabel('Metric')
plt.legend()
plt.yscale("log")

# %%
# plot loss (MSE) history

plt.figure(figsize=(10, 7))
plt.plot(range(1,len(hist_loss)+1), hist_loss, color='green', linestyle='-', label='train loss')
plt.plot(range(1,len(hist_vloss)+1),hist_vloss, color='blue', linestyle='-', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.yscale("log")

# %%
#test

# load the best model checkpoint
best_model = torch.load('best_model.pth')
best_model_epoch = best_model['epoch']
print(f"Best model was saved at {best_model_epoch} epochs\n")


model = DnCNN()
#model = UNet1D(1,1,32)
#model = DilatedResidualConvNet(1,1)
model.load_state_dict(best_model['model_state_dict'])
model.eval()

#let's do this on cpu (inference is fast)
model.to(torch.device('cpu'))

# test 10 cases
X_test_pt = X_test_pt[:10].type(torch.float).to(torch.device('cpu'))
prediction = model(X_test_pt)
# Out:
# Best model was saved at 79 epochs

# %%
prediction.shape
# Out:
# torch.Size([10, 1, 800])

# %%
#plot results
shift=0
plt.figure(figsize=(20,10))
for i in range(6):
    plt.subplot(2,6,i+1)
    plt.plot(X_test_pt[i+shift].permute(1,0).numpy().reshape(800,), '-b',label="noisy (input)") #input noisy spectrum
    plt.legend()
    plt.subplot(2,6,i+7)
    plt.plot(prediction[i+shift].permute(1,0).detach().numpy().reshape(800,), '-g',label="output") #cleaned spectrum predicted by te model
    plt.plot(Y_test_pt[i+shift].permute(1,0).numpy().reshape(800,), 'or', markersize=1, label = "clean (ground truth)") #ground truth
    plt.legend()
plt.tight_layout()

# %% [markdown]
# **spunti per sperimentare**
#
# *   test model variations: with and w/o BN, try theusing dilated convolutions ([dilation](https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html) parameter), try to analyise in parallel the input with different kernels:
#
#
# ```
# # code snippet example
# self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=20, padding='same', bias=False)
#     self.relu1 = nn.ReLU()
#
# hlayers = []
# for _ in range(num_layers):
#   hlayers.append(nn.Conv1d(in_channels=64, out_channels=64, kernel_size=20, padding='same', bias=False))
#   hlayers.append(nn.ReLU())
#
# self.central_block = nn.Sequential(*hlayers)
#
# self.conv1_b = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=5, padding='same', bias=False)
#     self.relu1_b = nn.ReLU()
#
# hlayers_b = []
# for _ in range(num_layers):
#   hlayers_b.append(nn.Conv1d(in_channels=64, out_channels=64, kernel_size=5, padding='same', bias=False))
#   hlayers_b.append(nn.ReLU())
#
# self.central_block_b = nn.Sequential(*hlayers_b)
#
# self.conv3 = nn.Conv1d(in_channels=64*2, out_channels=1, kernel_size=1, padding='same', bias=False)
#
# def forward(self, x):
#     out = self.relu1(self.conv1(x))
#     out = self.central_block(out)
#
#     out_b = self.relu1_b(self.conv1_b(x))
#     out_b = self.central_block_b(out_b)
#
#     out = torch.cat((out,out_b), dim=1)
#     out = self.conv3(out)
#
#     # residual learning (this way out become the clean spectrum and the network has only to learn the "noise")
#     out = x - out
#     return out
# ```
#
#
#
# *   test medium and high noise cases ...
